# %%
from OSRS_Ores import *
from Damage_Calc import *

# %%
help("OSRS_Ores")
# Out:
# Help on module OSRS_Ores:
#
# NAME
#     OSRS_Ores
#
# FUNCTIONS
#     addy_bar()
#
#     addy_price()
#
#     bar_prices()
#         #prints out all of the bar prices
#
#     bar_profit_ng(gold, coal, mith, addy, rune)
#         #calculates how much profit if user decides to smith ores into bars
#         #this doesn't include smithing gold bars
#
#     bar_profit_wg(gold, coal, mith, addy, rune)
#         #calculates how much profit if user decides to smith ores into bars
#         #this includes smithing gold bars
#
#     coal_cost(gold, coal, mith, addy, rune)
#         #calculates the cost of the coal needed by the coal price
#
#     coal_needed(gold, coal, mith, addy, rune)
#         #figures out how much coal is needed
#
#     coal_price()
#
#     gold_bar()
#
#     gold_price()
#
#     mith_bar()
#
#     mith_price()
#
#     ore_func()
#
#     ore_prices()
#         #prints out all of the ores prices
#
#     ore_profit(gold, coal, mith, addy, rune)
# ...

# %%
help("Damage_Calc")
# Out:
# Help on module Damage_Calc:
#
# NAME
#     Damage_Calc
#
# DESCRIPTION
#     #Creates a class that figures out "effective strength"
#     #This class will later convert the inputs into values for calculating
#
# CLASSES
#     builtins.object
#         Strength
#
#     class Strength(builtins.object)
#      |  Strength(strl, potb, pryb, othb, styb, strb)
#      |
#      |  #Creates a class that figures out "effective strength"
#      |  #This class will later convert the inputs into values for calculating
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, strl, potb, pryb, othb, styb, strb)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  potion_bonus(self)
#      |      #gives the potion bonus
#      |
#      |  prayer_bonus(self)
#      |      #gives the prayer bonus
#      |
#      |  set_bonus(self)
#      |      #gives the armor set bonus
#      |
#      |  style_bonus(self)
# ...

# %%
ore_func()
# Out:
# Starting up...
# Welcome to OSRS Ore Calc
# To get started, please fill out some info
# Gold Ores: 4000
# Coal Ores: 12000
# Mith Ores: 4000
# Addy Ores: 1000
# Rune Ores: 400
#
#
#
#
# Thank you
#
# Functions:
# 1. Ore Prices
# 2. Bar Prices
# 3. Coal Needed
# 4. Ore Profit
# 5. Bar Profit w/ smithing Gold
# 6. Bar Profit w/o smithing Gold
# E. Exit
#
# Please select a function: 1/2/3/4/5/6/E:
# 1
#
# Retrieving ore prices...
#
# Coal:	166gp
# Gold:	165gp
# Mith:	80gp
# Addy:	1216gp
# Rune:	11247gp
#
#
# Functions:
# 1. Ore Prices
# 2. Bar Prices
# 3. Coal Needed
# 4. Ore Profit
# 5. Bar Profit w/ smithing Gold
# 6. Bar Profit w/o smithing Gold
# E. Exit
#
# Please select a function: 1/2/3/4/5/6/E:
# 2
#
# Retrieving bar prices...
#
# Gold:	90gp
# Mith:	587gp
# Addy:	1908gp
# Rune:	12441gp
#
#
# Functions:
# 1. Ore Prices
# 2. Bar Prices
# 3. Coal Needed
# 4. Ore Profit
# 5. Bar Profit w/ smithing Gold
# 6. Bar Profit w/o smithing Gold
# E. Exit
#
# ...

# %%
damage_calculator()
# Out:
# Strength level: 99
# Potions:
# 1.None
# 2.Strength Potion
# 3.Super Strength/Overload
# 4.Zammy Brew
# 5.Dragon Battleaxe special
# Potion 1/2/3/4/5: 3
#
# Prayers:
# 1.None
# 2.Burst of Strength 5%
# 3.Superhuman Strength 10%
# 4.Ultimate Strength 15%
# 5.Chivalry 18%
# 6.Piety 23%
# Choose Prayer: 6
#
# Set Bonuses:
# 1.None/Dharok's
# 2.Void
# 3.Slayer Helm
# 4.Salve Amulet
# 5.Salve Amulet(e)
# 6.Inquisitor's Armour
# Set bonus 1/2/3/4/5/6: 2
#
# Attack Style:
# 1.Aggressive
# 2.Controlled
# 3.Accurate/Defensive
# Attack style: 1
#
# Strength Bonus: 120
#
#
#
#
# Max hit:47.217247812500005
